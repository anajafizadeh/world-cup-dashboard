# %% [markdown]
# World cup is less than a year away and the hype is starting to build up. That's why today I decided to create this dashboard to analyze some data from the past tournaments and make a final prediction on which country will win the World Cup 2026.
#
# To do that, I will be using matplotlib alongside pandas to visualize and analyze the data.

# %% [markdown]
# We start by importing the necessary modules:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

# %% [markdown]
# I've also created a python script that I will use to create my helper functions there to keep the dashboard clean.
#
# To import the file, we first need to add src/ to our system search:

# %%
sys.path.append(os.path.abspath("../src"))
from visualizations import plot_team_summary

# %% [markdown]
# Now let's read the data and preprocess it:

# %%
df = pd.read_csv('../data/matches_1930_2022.csv')

df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
df = df.dropna(subset=['home_team', 'away_team', 'home_score', 'away_score'])

# %% [markdown]
# Now that we have the data loaded, let's try the plot_team_summary functionality:

# %%
plot_team_summary(df, 'Argentina')

# %% [markdown]
# The bar chart above showcases the number of wins, losses and draws of Argentina throughout all World Cup Tournaments.
